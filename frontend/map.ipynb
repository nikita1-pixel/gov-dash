# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# 1. Load the PMC Shapefile 
# Replace 'pune_wards.shp' with your actual filename
fp = "pune_wards.shp"
map_df = gpd.read_file(fp)

# 2. Check the data (First 5 rows)
print(map_df.head())

# 3. Quick Visual Check
map_df.plot()
plt.title("Pune Municipal Corporation - Ward Map")
plt.show()
